# %%
#Import request and BeautifulSoupLibrary
import requests
from bs4 import BeautifulSoup

# %%
# Function to get a BeautifulSoup object containing the web structure
# and content of a URL
# Parameter: URL of the page we want to explore
# Return: BeautifulSoup object representing the page structure
def web_extract(url):
    # Make an HTTP request to the specified URL
    response = requests.get(url)

    # Declare a variable to hold the BeautifulSoup object
    soup = None

    # Check if the HTTP request was successful (status code 200)
    if response.status_code == 200:
        # Parse the page content with BeautifulSoup
        soup = BeautifulSoup(response.text, 'html.parser')
        print("Website successfully retrieved")
    # Handle the case where the HTTP request failed
    else:
        print(f"Failed to retrieve the web page. Status code: {response.status_code}")

    # Return the BeautifulSoup object (or None if the request failed)
    return soup

# %%
#The base URL: first page of the Innovate UK
baseURL = 'https://iuk.ktn-uk.org/projects/?_sft_programme=investor-partnerships-future-economy'

# %%
# Define the target class attributes to filter <a> tags
# This allows us to get the <a> tags that contain the href (link) 
# to each investor's description page on the Innovate UK website
targetClass = ['group', 'border-2', 'border-primary', 'flex', 'flex-col']

# %%
def getDescriptionPageLink(soup, targetClass):
    """
    Function to get the links to the description pages 
    from the BeautifulSoup object of a given URL.

    Parameters:
    soup (BeautifulSoup): BeautifulSoup object containing the web structure and content.
    targetClass (list): List of class attributes to target specific <a> tags.

    Returns:
    list: List of links to all investor pages from the BeautifulSoup object.
    """
    # Find all <a> tags with the specified class attributes
    target_a_tags = [tag for tag in soup.find_all('a')
                     if 'class' in tag.attrs and tag.attrs['class'] == targetClass]

    # Extract the 'href' attribute from each target <a> tag
    hrefList = [tag.get('href') for tag in target_a_tags]

    return hrefList

# %%
def getNextPage(soup):
    """
    Retrieves the URL of the next page from the BeautifulSoup object.

    Parameters:
    soup (BeautifulSoup): BeautifulSoup object representing the current page.

    Returns:
    str or None: URL of the next page if found, otherwise None.
    """
    next_atag = soup.find(lambda tag: tag.name == 'a' and tag.text == 'Next >')
    
    if next_atag:
        return next_atag.get('href')
    else:
        return None

# %%
def get_all_investorsLinkDescPagRecursively(URL, pageNum, target_class_, invList):
    """
    Recursively navigates through pages to extract links to investor description pages 
    from Innovate UK website.

    Parameters:
    URL (str): URL of the current page.
    pageNum (int): Current page number being processed.
    target_class_ (list): List of classes to filter <a> tags.
    invList (list): List of investor description page links collected so far.

    Returns:
    list: List of all investor description page links from all pages.
    """
    currentList = invList.copy()
    print(f"Page {pageNum}: ", end ='')
    soup = web_extract(URL)
    currentList.extend(getDescriptionPageLink(soup, target_class_))

    nextURL = getNextPage(soup)
    if nextURL:
        pageNum += 1
        return get_all_investorsLinkDescPagRecursively(nextURL, pageNum, target_class_, currentList)
    else:
        return currentList

# %%
# Compile a list of links to investor description pages on the Innovate UK website
compiledList = get_all_investorsLinkDescPagRecursively(baseURL, 1, targetClass, [])
# Out:
# Page 1: Website successfully retrieved
# Page 2: Website successfully retrieved
# Page 3: Website successfully retrieved
# Page 4: Website successfully retrieved
# Page 5: Website successfully retrieved
# Page 6: Website successfully retrieved

# %%
# Iterate through the compiled list of links to investor description pages
for link in compiledList:
    print(link)
# Out:
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/24haymarket-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/act-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/ada-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/albion-capital-group-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/amadeus-capital-partners/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/angel-academe/
# https://iuk.ktn-uk.org/projects/angelsessex/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/anglo-american-decarbonisation-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/anticus-partners/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/archangels/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/ascension-ventures-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/astanor/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/baltic-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/barclays-sustainable-impact-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/beringea/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/black-seed-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/bloc-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/boundary-capital-partners/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/cambridge-angels/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/cambridge-enterprise/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/cancer-research-horizons/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/carbon13/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/catapult-venture-managers-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/chrysalix-venture-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/cibus-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/clarendon-fund-managers-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/visvires-new-protein/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/clean-growth-fund/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/concept-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/cornerstone-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/cottagequinn-enterprises-ltd/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/counteract/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/cpt-capital-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/creative-uk/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/creator-fund/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/deep-science-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/deepbridge-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/deeptech-seed-fund/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/development-bank-of-wales/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/dsw-venture-capital-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/earlymarket-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/earth-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/east-innovate-ltd/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/ebico/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/eka-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/elbow-beach-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/elsoms-seeds/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/eos-advisory/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/epidarex-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/equity-gap/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/extantia/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/fearless-adventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/foresight-wae-technology-fund/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/fov-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/future-planet-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/gc-angels/
# https://iuk.ktn-uk.org/projects/green-angel-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/henley-business-angels/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/hermesa/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/hg-ventures/
# https://iuk.ktn-uk.org/projects/hiro-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/ip-group-plc/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/iq-capital-partners-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/jenson-funding-partners-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/kelvin-capital-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/khp-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/kindred-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/lcr-ventures-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/london-venture-partners/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/longwall-venture-partners-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/low-carbon-innovation-fund/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/m-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/maven/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/mercia-asset-management-plc/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/midven/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/minerva-business-angels/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/mmc-ventures-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/nesta/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/noba-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/northern-angel-hub/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/northern-gritstone-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/northstar-ventures-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/o2h-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/octopus-ventures-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/old-college-capital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/oneplanetcapital/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/oxford-science-enterprises-plc/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/oxford-technology/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/par-equity-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/parkwalk/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/pds-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/pioneering-ventures-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/praesidium-sa/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/praetura-ventures-limited/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/prostate-cancer-research/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/qantx/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/qubis/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/rabo-investments/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/regenerate-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/sainsburys-innovation-investments/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/science-creates-ventures-llp/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/setsquared/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/sfc-capital-ltd/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/social-tech-trust/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/sosv/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/speedinvest/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/start-codon/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/sure-valley-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/sustainable-venture-development-partners/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/techstart-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/tern-plc/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/conduit-connect/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/the-yield-lab/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/tsp-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/twin-path-ventures/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/two-magnolias/
# https://iuk.ktn-uk.org/projects/investor-partnerships-future-economy/zinc-ventures/
